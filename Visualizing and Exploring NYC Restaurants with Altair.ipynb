# %% [markdown]
# ## Visualizing and Exploring NYC Restaurant Inspection Data with Altair
#
#
# ### Table of Contents
# - [Cleaning of the data](#clean)
# - [Latest inspection grade by borough](#boro)
# - [Number of Inspections over time](#ts)
# - [Map of Restaurants with poor sanitation grade](#map_viz)
# - [Top 10 Cuisines and Inspections](#top_10)

# %% [markdown]
# <a id='clean'></a>
# ### Import NYC Restaurant Inspection Dataset
# We retrieved the latest NYC Restaurant Inspection Data from NYC Open Data, data as of 12/16/2019.

# %%
import pandas as pd
import numpy as np
df_rest = pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results.csv')
df_rest.head()
# Out:
#       CAMIS                 DBA       BORO BUILDING          STREET  ZIPCODE  \
# 0  50064946             RAVIOLO  Manhattan       57       7TH AVE S  10014.0
# 1  50000342       BLEND ASTORIA     Queens     3717     30TH AVENUE  11103.0
# 2  50040738         HAAGEN-DAZS     Queens     9015     QUEENS BLVD  11373.0
# 3  40797688  TRIPLE CROWN DINER     Queens    24827  JAMAICA AVENUE  11426.0
# 4  50068466  UNTAMED SANDWICHES  Manhattan      643   LEXINGTON AVE  10022.0
#
#         PHONE                                CUISINE DESCRIPTION  \
# 0  2124330818                                            Italian
# 1  3478134437  Latin (Cuban, Dominican, Puerto Rican, South &...
# 2  7187607220                                           American
# 3  7183474600                                           American
# 4  6468821877                                         Sandwiches
#
#   INSPECTION DATE                                             ACTION  ...  \
# 0      10/12/2017    Violations were cited in the following area(s).  ...
# 1      03/29/2018    Violations were cited in the following area(s).  ...
# 2      08/05/2016                   Establishment re-opened by DOHMH  ...
# 3      10/23/2018    Violations were cited in the following area(s).  ...
# 4      12/21/2018  No violations were recorded at the time of thi...  ...
#
#   RECORD DATE                                    INSPECTION TYPE   Latitude  \
# 0  11/25/2019      Pre-permit (Operational) / Initial Inspection  40.731524
# 1  11/25/2019              Cycle Inspection / Initial Inspection  40.764543
# 2  11/25/2019            Cycle Inspection / Reopening Inspection  40.733840
# 3  11/25/2019              Cycle Inspection / Initial Inspection  40.726252
# 4  11/25/2019  Administrative Miscellaneous / Initial Inspection  40.759229
#
#    Longitude Community Board Council District Census Tract        BIN  \
# 0 -74.003983           102.0              3.0       6700.0  1009946.0
# 1 -73.916371           401.0             22.0       6502.0  4010727.0
# 2 -73.871577           404.0             25.0      68300.0  4045999.0
# 3 -73.717491           413.0             23.0     161700.0  4177065.0
# 4 -73.970350           106.0              4.0      10000.0  1036487.0
#
#             BBL   NTA
# 0  1.005870e+09  MN23
# 1  4.006610e+09  QN70
# 2  4.018600e+09  QN29
# 3  4.086640e+09  QN43
# 4  1.013090e+09  MN19
#
# [5 rows x 26 columns]

# %%
df_rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397073 entries, 0 to 397072
# Data columns (total 26 columns):
# CAMIS                    397073 non-null int64
# DBA                      396400 non-null object
# BORO                     397073 non-null object
# BUILDING                 396820 non-null object
# STREET                   397062 non-null object
# ZIPCODE                  391506 non-null float64
# PHONE                    397056 non-null object
# CUISINE DESCRIPTION      397073 non-null object
# INSPECTION DATE          397073 non-null object
# ACTION                   395368 non-null object
# VIOLATION CODE           390979 non-null object
# VIOLATION DESCRIPTION    387719 non-null object
# CRITICAL FLAG            387719 non-null object
# SCORE                    379860 non-null float64
# GRADE                    200599 non-null object
# GRADE DATE               199037 non-null object
# RECORD DATE              397073 non-null object
# INSPECTION TYPE          395368 non-null object
# Latitude                 396641 non-null float64
# Longitude                396641 non-null float64
# Community Board          391085 non-null float64
# Council District         391085 non-null float64
# Census Tract             391085 non-null float64
# BIN                      389361 non-null float64
# BBL                      396641 non-null float64
# NTA                      391085 non-null object
# dtypes: float64(9), int64(1), object(16)
# memory usage: 78.8+ MB

# %%
# format date fields as datetime
date_cols = ['RECORD DATE', 'INSPECTION DATE']

for col in date_cols:
    df_rest[col] = pd.to_datetime(df_rest[col])

# %%
# # drop restaurants that don't have restaurant grade ABC 
# df_rest = df_rest[df_rest['GRADE'].isin(['A','B','C'])]

# %%
# drop records where lat/lng are nulls
df_rest = df_rest[(df_rest['Latitude'].notnull() & df_rest['Longitude'].notnull())]

# drop records where lat/long are 0
df_rest = df_rest[(df_rest['Latitude'] != 0) | (df_rest['Longitude'] != 0)]

# %%
# drop restaurants where DBA (name of restaurant) is null
df_rest = df_rest[df_rest['DBA'].notnull()]

# %%
# check for number of unique restaurants
df_rest['CAMIS'].nunique()
# Out:
# 26040

# %%
df_rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390422 entries, 0 to 397072
# Data columns (total 26 columns):
# CAMIS                    390422 non-null int64
# DBA                      390422 non-null object
# BORO                     390422 non-null object
# BUILDING                 390416 non-null object
# STREET                   390422 non-null object
# ZIPCODE                  390422 non-null float64
# PHONE                    390405 non-null object
# CUISINE DESCRIPTION      390422 non-null object
# INSPECTION DATE          390422 non-null datetime64[ns]
# ACTION                   389411 non-null object
# VIOLATION CODE           385145 non-null object
# VIOLATION DESCRIPTION    381937 non-null object
# CRITICAL FLAG            381937 non-null object
# SCORE                    374141 non-null float64
# GRADE                    197381 non-null object
# GRADE DATE               195822 non-null object
# RECORD DATE              390422 non-null datetime64[ns]
# INSPECTION TYPE          389411 non-null object
# Latitude                 390422 non-null float64
# Longitude                390422 non-null float64
# Community Board          390422 non-null float64
# Council District         390422 non-null float64
# Census Tract             390422 non-null float64
# BIN                      388674 non-null float64
# BBL                      390422 non-null float64
# NTA                      390422 non-null object
# dtypes: datetime64[ns](2), float64(9), int64(1), object(14)
# memory usage: 80.4+ MB

# %% [markdown]
# <a id='boro'></a>
# ### Let's visualize the number of restaurants by the latest inspection grade by borough
# We've filtered to the latast inspection for each restaurant and counted them by borough and grade.
# We also looked at the proportion of inspection grade within each borough.

# %%
import altair as alt
from vega_datasets import data

# %%
latest_inspection = df_rest.sort_values(['CAMIS', 'INSPECTION DATE'], 
                    ascending=[True, False]).groupby('CAMIS').head(1)

grade_count = latest_inspection.groupby(['BORO', 'GRADE'])['CAMIS'].nunique().reset_index()

chart1 = alt.Chart(grade_count).mark_bar(cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3).encode(
    x='GRADE',
    y='CAMIS',
    color='GRADE',
    column='BORO').properties(
    height=200,
    width=100
)

chart2 =alt.Chart(grade_count).mark_bar().encode(
    x=alt.X('sum(CAMIS)', stack="normalize"),
    y='BORO',
    color='GRADE').properties(
    height=200,
    width=600
)

alt.vconcat(chart1, chart2)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# <a id='ts'></a>
# ### Let's visualize the number of restaurants by grade over time by Inspection Date

# %%
#create timeseries data of monthly inspections 
df_dates = df_rest.copy()
df_dates.index = df_dates['INSPECTION DATE']
grades_ts = df_dates.groupby('GRADE').resample('MS')['CAMIS'].count().reset_index()

# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['INSPECTION DATE'], empty='none')

# Line Chart
line = alt.Chart().mark_line(interpolate='basis').encode(
    alt.X('INSPECTION DATE:T', axis=alt.Axis(title='')),
    alt.Y('CAMIS:Q', axis=alt.Axis(title='')),
    color='GRADE:N'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart().mark_point().encode(
    x='INSPECTION DATE:T',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'CAMIS:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart().mark_rule(color='gray').encode(
    x='INSPECTION DATE:T',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
inspections = alt.layer(line, selectors, points, rules, text,
                       data=grades_ts, 
                       width=600, height=400,title='Monthly Restaurant Inspections')
inspections
# inspections.save('inspections_trend.html')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# <a id='map_viz'></a>
#
# ### Create a map to visualize the locations of the restaurants that received letter C inspection grade. We will use the NYC NTA boundary mapping.
#
# Since there is a limitation of how many records can be rendered on a viz (5,000 rows) on Altair, we decided to visualize the location (lat/lng) of restaurants with poor inspection grade (C).

# %%
#geometries
nta_topo = 'https://raw.githubusercontent.com/grantpezeshki/NYC-topojson/master/NTA.topojson'
nta = alt.topo_feature(nta_topo, 'collection')

# C-grade restaurant locations 
latest_inspection = df_rest.sort_values(['CAMIS', 'INSPECTION DATE'], 
                    ascending=[True, False]).groupby('CAMIS').head(1)
c_grade = latest_inspection[latest_inspection['GRADE'] == 'C']

# filtering
input_dropdown = alt.binding_select(options=['Brooklyn','Queens','Staten Island', 'Manhattan', 'Bronx'])
selection = alt.selection_single(fields=['BORO'], bind=input_dropdown, name='Borough:')
color = alt.condition(selection,
                    alt.Color('Origin:N', legend=None),
                    alt.value('lightgray'))


# NYC nta background
background = alt.Chart(nta).mark_geoshape(
    stroke='white',
    strokeWidth=2
).encode(
    color=alt.value('#eee'),
).properties(
    width=600,
    height=500
).properties(
    title='Restaurants with Inspection Grade C'
)

#location points
points = alt.Chart(c_grade).mark_circle(
    size=8,
).encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    tooltip=['DBA', 'CUISINE DESCRIPTION', 'GRADE',
            'BUILDING','STREET','ZIPCODE', 'BORO'],
    color = color
).add_selection(
    selection
)

interactive_map = background + points
interactive_map
#interactive_map.save('Map of C-grade Restaurants.html')
# Out:
# alt.LayerChart(...)

# %%
c_grade
# Out:
#            CAMIS                                       DBA           BORO  \
# 16086   40369017                                  PALM TOO      Manhattan
# 48243   40370507                               THE PLAYERS      Manhattan
# 57244   40376944                               TOMOE SUSHI      Manhattan
# 14926   40382802                             PARNELL'S PUB      Manhattan
# 307489  40389504                                DALLAS BBQ      Manhattan
# 76607   40391594                      TAKAHACHI RESTAURANT      Manhattan
# 39584   40392927            NATIONAL RESTAURANT & CATERING       Brooklyn
# 81776   40394392                            PICCOLO ANGOLO      Manhattan
# 45228   40396892                        PARADISE ALLEY BAR         Queens
# 12800   40398045                               MIKES PIZZA      Manhattan
# 17818   40398688                                MASTER WOK       Brooklyn
# 204426  40400366                             VIN ET FLEURS      Manhattan
# 54900   40561162                         BRICCO RESTAURANT      Manhattan
# 7000    40570910               DIAMANTE POBLANO RESTAURANT          Bronx
# 134596  40573141                          PEPE ROSSO TO GO      Manhattan
# 9295    40577393                                 DON COQUI         Queens
# 26378   40594703                           RESTAURANT RIKI      Manhattan
# 4583    40716299                         CHUCK E. CHEESE'S  Staten Island
# 27588   40735273               EL PARAISO BAR & RESTAURANT         Queens
# 72555   40859014                                      CEBU       Brooklyn
# 106249  40936803               A. CHURRASQUEIRA RESTAURANT         Queens
# 3307    40979519                                    CLUB W          Bronx
# 1793    41004674               FLORIDITA RESTAURANT UPTOWN      Manhattan
# 141211  41011887                           THE CITY BAKERY      Manhattan
# 28873   41040222                    EL RINCONCITO DE NAGUA         Queens
# 127514  41056164                              CACIO & PEPE      Manhattan
# 7723    41119269         ROYAL INDIA PALACE AND RESTAURANT         Queens
# 145016  41130663                               ROSA'S CAFE         Queens
# 66122   41172855                    GABRIELA'S RESTAURANTE      Manhattan
# 46404   41177892                           LAKE COMO PIZZA      Manhattan
# ...          ...                                       ...            ...
# 74916   50077750                       FRIENDLY RESTAURANT         Queens
# 5278    50077827                     PARADISE JUICE GARDEN          Bronx
# 10895   50078961                    NEW LA CAYE RESTAURANT      Manhattan
# 23020   50079473                                      SKAL       Brooklyn
# 70489   50080258                               LA SORPRESA          Bronx
# 67339   50080360                               NYC SQUEEZE      Manhattan
# 2154    50080433                      CRUSTY & TASTY FOODS      Manhattan
# 61141   50080628      FREEDOM MEXICAN & ITALIAN RESTAURANT       Brooklyn
# 144465  50080719                             THE WOODSTOCK      Manhattan
# 28389   50083750                                  WEGO KTV         Queens
# 30181   50083813                                    AZTLAN         Queens
# 1517    50083834                  AANGAN INDIAN RESTAURANT      Manhattan
# 292320  50084846                                  FABRIQUE      Manhattan
# 57317   50085437                         DOMINICAN FLAVORS          Bronx
# 29108   50085705                      JOHN'S FRIED CHICKEN      Manhattan
# 103805  50085897                       TWINS DUMPLING KING       Brooklyn
# 29670   50086284                       TIPSYS BAR & LOUNGE         Queens
# 75725   50086652                                New Yee Li       Brooklyn
# 116395  50086657                       TJ'S TASTY CORNER 2       Brooklyn
# 7082    50087243                        LOS SAZONES LATINO          Bronx
# 69153   50087577               THREE BROTHERS FAMOUS PIZZA  Staten Island
# 17890   50088648                       DIAMOND'S TRATTORIA      Manhattan
# 51338   50088665                            HALAL MUNCHIES         Queens
# 149264  50088968                    SANBRA DOOR RESTAURANT          Bronx
# 162484  50090164                                  FLYWHEEL       Brooklyn
# 39386   50090427                     West End Taco Company      Manhattan
# 26059   50091305  TABLE 133 @ COURTYARD WORLD TRADE CENTER      Manhattan
# 22888   50091406                         SUKI ICHIRO SUSHI      Manhattan
# 4258    50093668                          MEETING CLUB INC         Queens
# 37329   50094742                                 ROTI-R-US       Brooklyn
#
#        BUILDING                   STREET  ZIPCODE       PHONE  \
# 16086       840                 2 AVENUE  10017.0  2126975198
# 48243        16      GRAMERCY PARK SOUTH  10003.0  2124756116
# 57244       172          THOMPSON STREET  10012.0  2127779346
# 14926       350         EAST   53 STREET  10022.0  2127531761
# 307489     1265                 3 AVENUE  10021.0  2127729393
# 76607        85                 AVENUE A  10009.0  2125056524
# 39584       273       BRIGHTON BEACH AVE  11235.0  7186461225
# 81776       621            HUDSON STREET  10014.0  2122299177
# 45228      4109               150 STREET  11355.0  7184606941
# 12800       415            SECOND AVENUE  10010.0  2125325196
# 17818      5100  KINGS PLAZA SHOPPING CT  11234.0  7182586943
# 204426       69          THOMPSON STREET  10012.0  2129665417
# 54900       304         WEST   56 STREET  10019.0  2122457160
# 7000       2431            JEROME AVENUE  10468.0  7183295240
# 134596      149          SULLIVAN STREET  10012.0  2126774555
# 9295       2818              31ST STREET  11102.0  7182747474
# 26378       141         EAST   45 STREET  10017.0  2129865604
# 4583       1775             SOUTH AVENUE  10314.0  7184941395
# 27588      9910                37 AVENUE  11368.0  9173097766
# 72555      8801                 3 AVENUE  11209.0  7184925095
# 106249     9529        SUTPHIN BOULEVARD  11435.0  7185235293
# 3307        673       HUNTS POINT AVENUE  10474.0  7188934466
# 1793       4162                 BROADWAY  10033.0  2129280653
# 141211        3         WEST   18 STREET  10011.0  2123661414
# 28873      7620           JAMAICA AVENUE  11421.0  7182960026
# 127514      182                 2 AVENUE  10003.0  2125055931
# 7723      11808          ATLANTIC AVENUE  11419.0  7188467600
# 145016     3003                38 AVENUE  11101.0  7187847906
# 66122       688          COLUMBUS AVENUE  10025.0  2129619600
# 46404      2549         AMSTERDAM AVENUE  10033.0  2127400110
# ...         ...                      ...      ...         ...
# 74916      1205                 40TH AVE  11101.0  7188433891
# 5278       1413       EDWARD L GRANT HWY  10452.0  3476069580
# 10895       858                 10TH AVE  10019.0  3472768867
# 23020       373                LEWIS AVE  11233.0  7186762288
# 70489        12         E KINGSBRIDGE RD  10468.0  7185617076
# 67339       956            LEXINGTON AVE  10021.0  7864003048
# 2154       1323                  2ND AVE  10021.0  6464787217
# 61141       679                  5TH AVE  11215.0  7183692575
# 144465      446                W 14TH ST  10014.0  2126332000
# 28389      3610                 UNION ST  11354.0  7183588895
# 30181      4506                 30TH AVE  11103.0  9172551722
# 1517       2701                 BROADWAY  10025.0  3477598989
# 292320      348                W 14TH ST  10014.0  9143304216
# 57317       145            BRUCKNER BLVD  10454.0  9292659909
# 29108      3853                 BROADWAY  10032.0  2125680004
# 103805      151                 AVENUE U  11223.0  7182668822
# 29670     10607              JAMAICA AVE  11418.0  9294998799
# 75725      6619       FORT HAMILTON PKWY  11219.0  7188338378
# 116395     1077               RUTLAND RD  11212.0  3472203986
# 7082       1048           WOODYCREST AVE  10452.0  7189287239
# 69153       189                 BROAD ST  10304.0  7187272682
# 17890       623                  9TH AVE  10036.0  6466091702
# 51338      2535              STEINWAY ST  11103.0  9177450585
# 149264      861            E TREMONT AVE  10460.0  7182943300
# 162484     1000                 SURF AVE  11224.0  7183735862
# 39386       301                W 96TH ST  10025.0  7186830839
# 26059       133             GREENWICH ST  10006.0  2123460088
# 22888      1694                  2ND AVE  10128.0  2123697088
# 4258      13659                 37TH AVE  11354.0  7183211233
# 37329      7902            FLATLANDS AVE  11236.0  3474024444
#
#                                       CUISINE DESCRIPTION INSPECTION DATE  \
# 16086                                            American      2019-09-30
# 48243                                            American      2019-03-19
# 57244                                            Japanese      2019-09-03
# 14926                                               Irish      2019-10-08
# 307489                                           Barbecue      2019-10-01
# 76607                                            Japanese      2019-07-23
# 39584                                             Russian      2019-06-28
# 81776                                             Italian      2019-07-24
# 45228                                            American      2019-08-07
# 12800                                       Pizza/Italian      2019-07-30
# 17818                                             Chinese      2019-10-11
# 204426                                             French      2019-06-12
# 54900                                             Italian      2019-05-29
# 7000                                              Mexican      2019-09-12
# 134596                                            Italian      2019-08-05
# 9295                                              Spanish      2019-06-01
# 26378                                            Japanese      2019-10-16
# 4583                                                Pizza      2019-10-17
# 27588   Latin (Cuban, Dominican, Puerto Rican, South &...      2019-07-13
# 72555                                            American      2019-08-21
# 106249                                         Portuguese      2019-07-24
# 3307                                             American      2019-10-02
# 1793    Latin (Cuban, Dominican, Puerto Rican, South &...      2019-08-01
# 141211                                           American      2019-07-12
# 28873   Latin (Cuban, Dominican, Puerto Rican, South &...      2019-08-22
# 127514                                            Italian      2019-07-02
# 7723                                               Indian      2019-06-20
# 145016                                            Spanish      2019-09-10
# 66122                                             Mexican      2019-08-05
# 46404                                               Pizza      2019-09-04
# ...                                                   ...             ...
# 74916                                             Chinese      2019-10-09
# 5278                       Juice, Smoothies, Fruit Salads      2019-08-21
# 10895                                           Caribbean      2019-06-26
# 23020                                            American      2019-09-06
# 70489                                             Spanish      2019-09-12
# 67339                      Juice, Smoothies, Fruit Salads      2019-10-21
# 2154                                         Delicatessen      2019-10-31
# 61141                                             Mexican      2019-10-01
# 144465                                              Pizza      2019-07-03
# 28389                                             Chinese      2019-08-10
# 30181                                            Peruvian      2019-08-01
# 1517                                               Indian      2019-09-16
# 292320                                             Bakery      2019-08-16
# 57317                                             Spanish      2019-09-20
# 29108                                             Spanish      2019-07-29
# 103805                                            Chinese      2019-07-22
# 29670                                           Caribbean      2019-08-01
# 75725                                             Chinese      2019-07-22
# 116395                                          Caribbean      2019-07-26
# 7082    Latin (Cuban, Dominican, Puerto Rican, South &...      2019-09-13
# 69153                                               Pizza      2019-10-23
# 17890                                             Italian      2019-08-15
# 51338                                            American      2019-10-16
# 149264                                            African      2019-07-25
# 162484                                           American      2019-10-01
# 39386                                             Mexican      2019-08-07
# 26059                                            American      2019-08-23
# 22888                                            Japanese      2019-06-06
# 4258                                        Chinese/Cuban      2019-07-08
# 37329                                           Caribbean      2019-08-28
#
#                                                  ACTION  ... RECORD DATE  \
# 16086   Violations were cited in the following area(s).  ...  2019-11-25
# 48243   Violations were cited in the following area(s).  ...  2019-11-25
# 57244   Violations were cited in the following area(s).  ...  2019-11-25
# 14926   Violations were cited in the following area(s).  ...  2019-11-25
# 307489  Violations were cited in the following area(s).  ...  2019-11-25
# 76607   Violations were cited in the following area(s).  ...  2019-11-25
# 39584   Violations were cited in the following area(s).  ...  2019-11-25
# 81776   Violations were cited in the following area(s).  ...  2019-11-25
# 45228   Violations were cited in the following area(s).  ...  2019-11-25
# 12800   Violations were cited in the following area(s).  ...  2019-11-25
# 17818   Violations were cited in the following area(s).  ...  2019-11-25
# 204426  Violations were cited in the following area(s).  ...  2019-11-25
# 54900   Violations were cited in the following area(s).  ...  2019-11-25
# 7000    Violations were cited in the following area(s).  ...  2019-11-25
# 134596  Violations were cited in the following area(s).  ...  2019-11-25
# 9295    Violations were cited in the following area(s).  ...  2019-11-25
# 26378   Violations were cited in the following area(s).  ...  2019-11-25
# 4583    Violations were cited in the following area(s).  ...  2019-11-25
# 27588   Violations were cited in the following area(s).  ...  2019-11-25
# 72555   Violations were cited in the following area(s).  ...  2019-11-25
# 106249  Violations were cited in the following area(s).  ...  2019-11-25
# 3307    Violations were cited in the following area(s).  ...  2019-11-25
# 1793    Violations were cited in the following area(s).  ...  2019-11-25
# 141211  Violations were cited in the following area(s).  ...  2019-11-25
# 28873   Violations were cited in the following area(s).  ...  2019-11-25
# 127514  Violations were cited in the following area(s).  ...  2019-11-25
# 7723    Violations were cited in the following area(s).  ...  2019-11-25
# 145016  Violations were cited in the following area(s).  ...  2019-11-25
# 66122   Violations were cited in the following area(s).  ...  2019-11-25
# 46404   Violations were cited in the following area(s).  ...  2019-11-25
# ...                                                 ...  ...         ...
# 74916   Violations were cited in the following area(s).  ...  2019-11-25
# 5278    Violations were cited in the following area(s).  ...  2019-11-25
# 10895   Violations were cited in the following area(s).  ...  2019-11-25
# 23020   Violations were cited in the following area(s).  ...  2019-11-25
# 70489   Violations were cited in the following area(s).  ...  2019-11-25
# 67339   Violations were cited in the following area(s).  ...  2019-11-25
# 2154    Violations were cited in the following area(s).  ...  2019-11-25
# 61141   Violations were cited in the following area(s).  ...  2019-11-25
# 144465  Violations were cited in the following area(s).  ...  2019-11-25
# 28389   Violations were cited in the following area(s).  ...  2019-11-25
# 30181   Violations were cited in the following area(s).  ...  2019-11-25
# 1517    Violations were cited in the following area(s).  ...  2019-11-25
# 292320  Violations were cited in the following area(s).  ...  2019-11-25
# 57317   Violations were cited in the following area(s).  ...  2019-11-25
# 29108   Violations were cited in the following area(s).  ...  2019-11-25
# 103805  Violations were cited in the following area(s).  ...  2019-11-25
# 29670   Violations were cited in the following area(s).  ...  2019-11-25
# 75725   Violations were cited in the following area(s).  ...  2019-11-25
# 116395  Violations were cited in the following area(s).  ...  2019-11-25
# 7082    Violations were cited in the following area(s).  ...  2019-11-25
# 69153   Violations were cited in the following area(s).  ...  2019-11-25
# 17890   Violations were cited in the following area(s).  ...  2019-11-25
# 51338   Violations were cited in the following area(s).  ...  2019-11-25
# 149264  Violations were cited in the following area(s).  ...  2019-11-25
# 162484  Violations were cited in the following area(s).  ...  2019-11-25
# 39386   Violations were cited in the following area(s).  ...  2019-11-25
# 26059   Violations were cited in the following area(s).  ...  2019-11-25
# 22888   Violations were cited in the following area(s).  ...  2019-11-25
# 4258    Violations were cited in the following area(s).  ...  2019-11-25
# 37329   Violations were cited in the following area(s).  ...  2019-11-25
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 16086           Cycle Inspection / Re-inspection  40.751554 -73.970927
# 48243           Cycle Inspection / Re-inspection  40.737776 -73.986483
# 57244           Cycle Inspection / Re-inspection  40.727712 -74.000256
# 14926           Cycle Inspection / Re-inspection  40.756238 -73.965959
# 307489          Cycle Inspection / Re-inspection  40.770262 -73.960218
# 76607           Cycle Inspection / Re-inspection  40.725166 -73.984191
# 39584           Cycle Inspection / Re-inspection  40.576889 -73.964816
# 81776           Cycle Inspection / Re-inspection  40.738048 -74.005618
# 45228           Cycle Inspection / Re-inspection  40.762389 -73.813815
# 12800           Cycle Inspection / Re-inspection  40.738346 -73.980579
# 17818           Cycle Inspection / Re-inspection  40.609929 -73.922282
# 204426          Cycle Inspection / Re-inspection  40.724352 -74.003074
# 54900           Cycle Inspection / Re-inspection  40.766244 -73.983877
# 7000            Cycle Inspection / Re-inspection  40.862080 -73.901614
# 134596          Cycle Inspection / Re-inspection  40.727086 -74.001844
# 9295            Cycle Inspection / Re-inspection  40.768010 -73.920436
# 26378           Cycle Inspection / Re-inspection  40.753164 -73.974161
# 4583            Cycle Inspection / Re-inspection  40.601621 -74.192970
# 27588           Cycle Inspection / Re-inspection  40.752300 -73.867993
# 72555           Cycle Inspection / Re-inspection  40.621937 -74.031671
# 106249          Cycle Inspection / Re-inspection  40.698212 -73.806331
# 3307            Cycle Inspection / Re-inspection  40.813878 -73.885179
# 1793            Cycle Inspection / Re-inspection  40.847056 -73.938175
# 141211          Cycle Inspection / Re-inspection  40.738729 -73.992321
# 28873           Cycle Inspection / Re-inspection  40.691594 -73.865363
# 127514          Cycle Inspection / Re-inspection  40.730689 -73.986134
# 7723            Cycle Inspection / Re-inspection  40.693861 -73.828684
# 145016          Cycle Inspection / Re-inspection  40.754127 -73.932656
# 66122           Cycle Inspection / Re-inspection  40.791078 -73.968826
# 46404           Cycle Inspection / Re-inspection  40.851513 -73.928396
# ...                                          ...        ...        ...
# 74916           Cycle Inspection / Re-inspection  40.755985 -73.942677
# 5278            Cycle Inspection / Re-inspection  40.842144 -73.922584
# 10895           Cycle Inspection / Re-inspection  40.768688 -73.988852
# 23020           Cycle Inspection / Re-inspection  40.682646 -73.934974
# 70489           Cycle Inspection / Re-inspection  40.867307 -73.897018
# 67339   Pre-permit (Operational) / Re-inspection  40.768907 -73.963317
# 2154            Cycle Inspection / Re-inspection  40.767273 -73.959491
# 61141           Cycle Inspection / Re-inspection  40.661667 -73.993069
# 144465  Pre-permit (Operational) / Re-inspection  40.741784 -74.007387
# 28389           Cycle Inspection / Re-inspection  40.763482 -73.828056
# 30181           Cycle Inspection / Re-inspection  40.761926 -73.910845
# 1517            Cycle Inspection / Re-inspection  40.799200 -73.968501
# 292320  Pre-permit (Operational) / Re-inspection  40.740370 -74.004027
# 57317           Cycle Inspection / Re-inspection  40.803782 -73.920219
# 29108           Cycle Inspection / Re-inspection  40.836316 -73.943237
# 103805          Cycle Inspection / Re-inspection  40.596375 -73.978705
# 29670   Pre-permit (Operational) / Re-inspection  40.695320 -73.840851
# 75725   Pre-permit (Operational) / Re-inspection  40.629970 -74.010192
# 116395          Cycle Inspection / Re-inspection  40.664101 -73.924183
# 7082            Cycle Inspection / Re-inspection  40.833524 -73.927292
# 69153           Cycle Inspection / Re-inspection  40.624167 -74.080952
# 17890   Pre-permit (Operational) / Re-inspection  40.759822 -73.991625
# 51338           Cycle Inspection / Re-inspection  40.767551 -73.911999
# 149264  Pre-permit (Operational) / Re-inspection  40.843064 -73.886361
# 162484  Pre-permit (Operational) / Re-inspection  40.575426 -73.978006
# 39386           Cycle Inspection / Re-inspection  40.795370 -73.973476
# 26059   Pre-permit (Operational) / Re-inspection  40.709461 -74.012931
# 22888   Pre-permit (Operational) / Re-inspection  40.778965 -73.950930
# 4258    Pre-permit (Operational) / Re-inspection  40.761974 -73.829338
# 37329   Pre-permit (Operational) / Re-inspection  40.635079 -73.913915
#
#        Community Board Council District Census Tract        BIN           BBL  \
# 16086            106.0              4.0       9000.0  1038763.0  1.013370e+09
# 48243            106.0              2.0       5000.0  1017938.0  1.008750e+09
# 57244            102.0              1.0       6500.0  1084919.0  1.005250e+09
# 14926            106.0              4.0       9800.0  1039803.0  1.013450e+09
# 307489           108.0              4.0      12600.0  1085193.0  1.014270e+09
# 76607            103.0              2.0       3200.0  1005764.0  1.004328e+09
# 39584            313.0             48.0      36200.0  3326863.0  3.086720e+09
# 81776            102.0              3.0       7900.0  1011419.0  1.006250e+09
# 45228            407.0             20.0     116700.0  4114918.0  4.050580e+09
# 12800            106.0              2.0       6400.0  1078779.0  1.009040e+09
# 17818            318.0             46.0      69800.0  3326830.0  3.084700e+09
# 204426           102.0              3.0       4700.0  1077743.0  1.004890e+09
# 54900            104.0              3.0      13900.0  1025438.0  1.010460e+09
# 7000             207.0             14.0      25300.0  2014332.0  2.031990e+09
# 134596           102.0              3.0       4900.0  1008045.0  1.005170e+09
# 9295             401.0             22.0       7100.0  4007843.0  4.005988e+09
# 26378            106.0              4.0       9200.0  1036192.0  1.013000e+09
# 4583             502.0             50.0      29102.0  5104123.0  5.028000e+09
# 27588            403.0             21.0      40700.0  4043958.0  4.017620e+09
# 72555            310.0             43.0       6000.0  3154055.0  3.060620e+09
# 106249           412.0             28.0      20800.0  4214527.0  4.100270e+09
# 3307             202.0             17.0       9300.0  2006752.0  2.027661e+09
# 1793             112.0             10.0      26300.0  1063559.0  1.021450e+09
# 141211           105.0              3.0       5400.0  1015450.0  1.008200e+09
# 28873            409.0             30.0        400.0  4183078.0  4.089050e+09
# 127514           103.0              2.0       4000.0  1006473.0  1.004530e+09
# 7723             409.0             28.0      12000.0  4199105.0  4.094360e+09
# 145016           401.0             26.0       5100.0  4430653.0  4.003720e+09
# 66122            107.0              6.0      17700.0  1084572.0  1.012240e+09
# 46404            112.0             10.0      26700.0  1063584.0  1.021490e+09
# ...                ...              ...          ...        ...           ...
# 74916            401.0             26.0       8500.0  4441822.0  4.004721e+09
# 5278             204.0             16.0      21100.0  2092829.0  2.025210e+09
# 10895            104.0              3.0      13900.0  1026857.0  1.010660e+09
# 23020            303.0             36.0      29700.0  3046797.0  3.016700e+09
# 70489            207.0             14.0      40100.0  2014136.0  2.031910e+09
# 67339            108.0              4.0      12000.0  1042509.0  1.014040e+09
# 2154             108.0              4.0      12600.0  1072223.0  1.014248e+09
# 61141            307.0             38.0      14500.0  3017373.0  3.008910e+09
# 144465           102.0              3.0       7900.0  1012224.0  1.006460e+09
# 28389            407.0             20.0      86900.0  4112354.0  4.049770e+09
# 30181            401.0             22.0      15100.0  4012676.0  4.007140e+09
# 1517             107.0              6.0      19100.0  1056562.0  1.018750e+09
# 292320           102.0              3.0       7700.0  1011693.0  1.006290e+09
# 57317            201.0              8.0       1900.0  2000019.0  2.022610e+09
# 29108            112.0              7.0      24500.0  1063351.0  1.021370e+09
# 103805           311.0             47.0      40000.0  3191086.0  3.070980e+09
# 29670            409.0             32.0       2600.0  4192085.0  4.092020e+09
# 75725            310.0             43.0      21000.0  3142359.0  3.057570e+09
# 116395           317.0             41.0      89200.0  3099544.0  3.045990e+09
# 7082             204.0              8.0      18900.0  2003140.0  2.025080e+09
# 69153            501.0             49.0       2100.0  5014047.0  5.005410e+09
# 17890            104.0              3.0      12100.0  1026414.0  1.010540e+09
# 51338            401.0             22.0      14300.0  4011388.0  4.006840e+09
# 149264           206.0             17.0      36501.0  2013089.0  2.031170e+09
# 162484           313.0             47.0      35200.0  3245158.0  3.086960e+09
# 39386            107.0              6.0      18300.0  1057057.0  1.018870e+09
# 26059            101.0              1.0       1300.0  1089248.0  1.000520e+09
# 22888            108.0              5.0      14602.0  1050061.0  1.015500e+09
# 4258             407.0             20.0      86900.0  4112365.0  4.049770e+09
# 37329            318.0             46.0      95600.0  3224863.0  3.080160e+09
#
#          NTA
# 16086   MN19
# 48243   MN21
# 57244   MN23
# 14926   MN19
# 307489  MN31
# 76607   MN22
# 39584   BK19
# 81776   MN23
# 45228   QN51
# 12800   MN21
# 17818   BK45
# 204426  MN24
# 54900   MN15
# 7000    BX30
# 134596  MN24
# 9295    QN71
# 26378   MN19
# 4583    SI05
# 27588   QN26
# 72555   BK31
# 106249  QN61
# 3307    BX27
# 1793    MN36
# 141211  MN13
# 28873   QN53
# 127514  MN22
# 7723    QN54
# 145016  QN68
# 66122   MN12
# 46404   MN35
# ...      ...
# 74916   QN68
# 5278    BX26
# 10895   MN15
# 23020   BK61
# 70489   BX05
# 67339   MN40
# 2154    MN31
# 61141   BK32
# 144465  MN23
# 28389   QN22
# 30181   QN70
# 1517    MN12
# 292320  MN23
# 57317   BX39
# 29108   MN36
# 103805  BK29
# 29670   QN54
# 75725   BK30
# 116395  BK81
# 7082    BX26
# 69153   SI37
# 17890   MN15
# 51338   QN70
# 149264  BX17
# 162484  BK21
# 39386   MN12
# 26059   MN25
# 22888   MN32
# 4258    QN22
# 37329   BK50
#
# [226 rows x 26 columns]

# %% [markdown]
# Count the number C restaurants by cuisine type

# %%
#count number C restaurants by cuisine type
latest_inspection = df_rest.sort_values(['CAMIS', 'INSPECTION DATE'], 
                    ascending=[True, False]).groupby('CAMIS').head(1)
c_grade = latest_inspection[latest_inspection['GRADE'] == 'C']
c_cuis_cnt = c_grade.groupby('CUISINE DESCRIPTION')['CAMIS']\
            .count().reset_index().sort_values('CAMIS', ascending=False)

#Grade C Grades by cuisine type
bars = alt.Chart(c_cuis_cnt).mark_bar(color ='steelblue').encode(
    x=alt.X('CAMIS:Q', 
    axis=alt.Axis(title ='# of C Grades')),

    y=alt.Y('CUISINE DESCRIPTION:N',
            sort='-x',
            axis=alt.Axis(title ='Cuisine')
    )

)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='CAMIS:Q'
)

cusin_bar = (bars + text).properties(height=500,width=100)
cusin_bar
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Combine the interactive map with bar chart

# %%
alt.hconcat(interactive_map ,cusin_bar)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# <a id='top_10'></a>
# ### Percentage of Inspection Grades for the top 10 cuisine (by count and inspection grade)

# %%
#top 10 cuisine by counts
latest_inspection = df_rest.sort_values(['CAMIS', 'INSPECTION DATE'], 
                    ascending=[True, False]).groupby('CAMIS').head(1)
cusines = latest_inspection.groupby(['CUISINE DESCRIPTION'])['CAMIS'].count().reset_index()
topcusines = cusines.sort_values('CAMIS', ascending=False).iloc[:20,:]
topcusines

bars = alt.Chart(topcusines).mark_bar(color ='steelblue').encode(
    x=alt.X('CAMIS:Q', 
    axis=alt.Axis(title ='# of Restaurants')),

    y=alt.Y('CUISINE DESCRIPTION:N',
            sort='-x',
            axis=alt.Axis(title ='Cuisine')
    )

)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  
).encode(
    text='CAMIS:Q'
)

top10cuisine = (bars + text).properties(height=500,width=200)

#Top 10 cusine types by inspection grades 
top10cuis_insp = latest_inspection[latest_inspection['CUISINE DESCRIPTION']\
                  .isin(topcusines['CUISINE DESCRIPTION'].to_list())]\
                    .groupby(['CUISINE DESCRIPTION', 'GRADE'])['CAMIS'].count().reset_index()

top10grade = alt.Chart(top10cuis_insp).mark_bar().encode(
                        x=alt.X('sum(CAMIS)', stack="normalize"),
                        y='CUISINE DESCRIPTION',
                        color='GRADE').properties(
                        height=500,
                        width=200
                    )

alt.hconcat(top10cuisine, top10grade)
# Out:
# alt.HConcatChart(...)
